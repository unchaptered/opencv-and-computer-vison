# %%
import numpy as np

# %%
import matplotlib.pyplot as plt   # 컴퓨터 안의 이미지들을 구성하고 진열할 수 있게 해주는 라이브러리
# %matplotlib inline                # 최신 버전의 Jupiter.Lab 에서는 필요하지 않지만, 그래도 넣어주는 것이 좋다.

# %%
from PIL import Image             # Python Imaging Library

# %%
pic = Image.open('../../DATA/00-puppy.jpg')

# %%
print(pic)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300 at 0x2CDC1582438>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_array.shape
# Out:
# (1300, 1950, 3)

# %%
pic_array = np.asarray(pic)

# %%
plt.imshow(pic_array)

# %%
# R:G:B
# 붉은색 채널
# 하얗게 보일 수록, 붉은색이 많이 포함되었다는 뜻

pic_red = pic_array.copy()
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
# R:G:B
# 녹색 채널
# 하얗게 보일 수록, 녹색이 많이 포함되었다는 뜻

pic_green = pic_array.copy()
plt.imshow(pic_green[:,:,1], cmap='gray')

# %%
# R:G:
# 파란색 채널
# 하얗게 보일 수록, 파란색이 많이 포함되었다는 뜻

pic_blue = pic_array.copy()
plt.imshow(pic_blue[:,:,2], cmap='gray')

# %%
test_1 = pic_array.copy()
test_1[:,:,1] = 0
plt.imshow(test_1, cmap='gray')

# %%
test_2 = pic_array.copy()
test_2[:,:,2] = 0
plt.imshow(test_2, cmap='gray')

# %%
test_3 = pic_array.copy()
test_3[:,:,0] = 0
plt.imshow(test_3, cmap='gray')
